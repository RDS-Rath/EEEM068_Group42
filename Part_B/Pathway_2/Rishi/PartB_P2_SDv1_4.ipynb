# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/huggingface/diffusers.git
# %cd diffusers

# !pip install -e .
# !pip install accelerate transformers torchvision torch datasets pytorch-fid safetensors
# !pip install bitsandbytes
# !pip install clean-fid
# !pip install xformers
# Out:
# fatal: destination path 'diffusers' already exists and is not an empty directory.
# /content/diffusers
# Obtaining file:///content/diffusers
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers==0.39.0.dev0) (8.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers==0.39.0.dev0) (3.29.0)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.39.0.dev0) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.39.0.dev0) (1.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from diffusers==0.39.0.dev0) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.39.0.dev0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers==0.39.0.dev0) (2.32.4)
# Requirement already satisfied: safetensors>=0.8.0-rc.0 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.39.0.dev0) (0.8.0rc0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers==0.39.0.dev0) (11.3.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.39.0.dev0) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.39.0.dev0) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.39.0.dev0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers==0.39.0.dev0) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers==0.39.0.dev0) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (1.4.3)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (0.24.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (4.15.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers==0.39.0.dev0) (3.23.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.39.0.dev0) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.39.0.dev0) (2.5.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers==0.39.0.dev0) (0.1.2)
# Building wheels for collected packages: diffusers
#   Building editable for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.39.0.dev0-0.editable-py3-none-any.whl size=11407 sha256=ce7b1e762cc7669771fb72ada78a43030ccfdc909a5a99acd0ed5c4ef9233d41
#   Stored in directory: /tmp/pip-ephem-wheel-cache-obn0daay/wheels/8a/fc/09/385efb77b455b2fd4a656c950079c93147e1f50ae614e51beb
# Successfully built diffusers
# Installing collected packages: diffusers
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.39.0.dev0
#     Uninstalling diffusers-0.39.0.dev0:
#       Successfully uninstalled diffusers-0.39.0.dev0
# Successfully installed diffusers-0.39.0.dev0
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.25.0+cu128)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: pytorch-fid in /usr/local/lib/python3.12/dist-packages (0.3.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (0.8.0rc0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (26.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (1.11.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.29.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.5.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pytorch-fid) (1.16.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (0.24.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.4.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2026.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate) (0.1.2)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.49.2)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.10.0+cu128)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (26.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3,>=2.3->bitsandbytes) (1.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)
# Requirement already satisfied: clean-fid in /usr/local/lib/python3.12/dist-packages (0.1.35)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from clean-fid) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from clean-fid) (0.25.0+cu128)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.12/dist-packages (from clean-fid) (2.0.2)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from clean-fid) (1.16.3)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.12/dist-packages (from clean-fid) (4.67.3)
# Requirement already satisfied: pillow>=8.1 in /usr/local/lib/python3.12/dist-packages (from clean-fid) (11.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from clean-fid) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->clean-fid) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->clean-fid) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->clean-fid) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->clean-fid) (2026.4.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->clean-fid) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->clean-fid) (1.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->clean-fid) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->clean-fid) (3.0.3)
# Requirement already satisfied: xformers in /usr/local/lib/python3.12/dist-packages (0.0.35)
# Requirement already satisfied: torch>=2.10 in /usr/local/lib/python3.12/dist-packages (from xformers) (2.10.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xformers) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->xformers) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.10->xformers) (1.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.10->xformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.10->xformers) (3.0.3)

# %%
from huggingface_hub import login
login("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")

# %%
BASE = "/content"

IMG_DIR = "/content/drive/MyDrive/Surrey_AML_CW/CelebA-HQ-img"
ATTR_PATH = "/content/drive/MyDrive/Surrey_AML_CW/CelebAMask-HQ-attribute-anno.csv"

TRAIN_DIR = "/content/data/train"
TEST_DIR  = "/content/data/test"

# %%
import os

IMG_DIR = "/content/drive/MyDrive/Surrey_AML_CW/CelebA-HQ-img"

print(f"Checking for images in: {IMG_DIR}")

if not os.path.isdir(IMG_DIR):
    raise ValueError(f"Directory does not exist: {IMG_DIR}")

# Load all images (case-insensitive, multiple formats)
all_imgs = [
    os.path.join(IMG_DIR, f)
    for f in os.listdir(IMG_DIR)
    if f.lower().endswith((".jpg", ".jpeg", ".png"))
]

print("Total images found:", len(all_imgs))

if len(all_imgs) == 0:
    raise ValueError("No images found. Check extensions or folder structure.")
# Out:
# Checking for images in: /content/drive/MyDrive/Surrey_AML_CW/CelebA-HQ-img
# Total images found: 30001

# %%
import os, random

IMG_DIR = "/content/drive/MyDrive/Surrey_AML_CW/CelebA-HQ-img"

all_imgs = [f for f in os.listdir(IMG_DIR) if f.endswith(".jpg")]

random.seed(42)
random.shuffle(all_imgs)

n = len(all_imgs)

train_end = int(0.9 * n)   # 90% → ~27k

train_files = all_imgs[:train_end]
test_files  = all_imgs[train_end:]

print("Train:", len(train_files))
print("Test:", len(test_files))
print("Total:", len(train_files) + len(test_files))
# Out:
# Train: 27000
# Test: 3001
# Total: 30001

# %%
import os, shutil

TRAIN_DIR = "/content/data/train"
TEST_DIR  = "/content/data/test"

os.makedirs(TRAIN_DIR, exist_ok=True)
os.makedirs(TEST_DIR, exist_ok=True)

def clear(folder):
    for f in os.listdir(folder):
        os.remove(os.path.join(folder, f))

clear(TRAIN_DIR)
clear(TEST_DIR)

for f in train_files:
    shutil.copy(os.path.join(IMG_DIR, f), os.path.join(TRAIN_DIR, f))

for f in test_files:
    shutil.copy(os.path.join(IMG_DIR, f), os.path.join(TEST_DIR, f))

print("Train dir:", len(os.listdir(TRAIN_DIR)))
print("Test dir:", len(os.listdir(TEST_DIR)))
# Out:
# Train dir: 27000
# Test dir: 3001

# %%
import os

print("Train exists:", os.path.exists("/content/data/train"))

if os.path.exists("/content/data/train"):
    print("Train count:", len(os.listdir("/content/data/train")))

print("Test exists:", os.path.exists("/content/data/test"))

if os.path.exists("/content/data/test"):
    print("Test count:", len(os.listdir("/content/data/test")))
# Out:
# Train exists: True
# Train count: 27000
# Test exists: True
# Test count: 3001

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os

plt.figure(figsize=(6,6))

for i in range(9):
    img = Image.open(os.path.join(TRAIN_DIR, train_files[i]))
    plt.subplot(3,3,i+1)
    plt.imshow(img)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import pandas as pd

df = pd.read_csv(ATTR_PATH)

# Rename first column to image
df = df.rename(columns={df.columns[0]: "image"})

attribute_columns = list(df.columns[1:])

def build_caption(row):

    attrs = []

    for attr in attribute_columns:

        if row[attr] == 1:
            attrs.append(attr)

    return "a face with " + ", ".join(attrs)

df["text"] = df.apply(build_caption, axis=1)

train_names = [f.split("/")[-1] for f in train_files]

df = df[df["image"].isin(train_names)]

metadata = pd.DataFrame({
    "file_name": df["image"],
    "text": df["text"]
})

metadata.to_csv(
    "/content/data/train/metadata.csv",
    index=False
)

print(metadata.head())
print("\nTotal training captions:", len(metadata))
# Out:
#   file_name                                               text
# 0     0.jpg  a face with Arched_Eyebrows, Attractive, Bags_...
# 1     1.jpg  a face with Arched_Eyebrows, Attractive, Blond...
# 4     4.jpg  a face with Big_Lips, Brown_Hair, Mouth_Slight...
# 5     5.jpg  a face with Attractive, Blond_Hair, No_Beard, ...
# 6     6.jpg  a face with Attractive, Bags_Under_Eyes, No_Be...
#
# Total training captions: 26999

# %%
print(df.columns)
# Out:
# Index(['image', '5_o_Clock_Shadow', 'Arched_Eyebrows', 'Attractive',
#        'Bags_Under_Eyes', 'Bald', 'Bangs', 'Big_Lips', 'Big_Nose',
#        'Black_Hair', 'Blond_Hair', 'Blurry', 'Brown_Hair', 'Bushy_Eyebrows',
#        'Chubby', 'Double_Chin', 'Eyeglasses', 'Goatee', 'Gray_Hair',
#        'Heavy_Makeup', 'High_Cheekbones', 'Male', 'Mouth_Slightly_Open',
#        'Mustache', 'Narrow_Eyes', 'No_Beard', 'Oval_Face', 'Pale_Skin',
#        'Pointy_Nose', 'Receding_Hairline', 'Rosy_Cheeks', 'Sideburns',
#        'Smiling', 'Straight_Hair', 'Wavy_Hair', 'Wearing_Earrings',
#        'Wearing_Hat', 'Wearing_Lipstick', 'Wearing_Necklace',
#        'Wearing_Necktie', 'Young', 'text'],
#       dtype='object')

# %%
# !ls /content/data/train | head
# Out:
# 0.jpg
# 10001.jpg
# 10002.jpg
# 10004.jpg
# 10005.jpg
# 10006.jpg
# 10007.jpg
# 10008.jpg
# 10009.jpg
# 1000.jpg

# %%
# !accelerate config default
# Out:
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %%
# %cd /content/diffusers/examples/text_to_image
# !pwd
# Out:
# /content/diffusers/examples/text_to_image
# /content/diffusers/examples/text_to_image

# %%
# !accelerate launch train_text_to_image.py \
  --pretrained_model_name_or_path="CompVis/stable-diffusion-v1-4" \
  --train_data_dir="/content/data/train" \
  --resolution=512 \
  --center_crop \
  --random_flip \
  --train_batch_size=8 \
  --gradient_accumulation_steps=1 \
  --learning_rate=5e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=1000 \
  --max_train_steps=30000 \
  --use_ema \
  --dataloader_num_workers=8 \
  --checkpointing_steps=10000 \
  --checkpoints_total_limit=3 \
  --output_dir="/content/sd14_celebahq" \
  --seed=42 \
  --mixed_precision="fp16" \
  --report_to="tensorboard" \
  --logging_dir="/content/sd14_celebahq/logs"
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# INFO:__main__:[RANK 0] Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# scheduler_config.json: 100% 313/313 [00:00<00:00, 2.71MB/s]
# {'thresholding', 'variance_type', 'sample_max_value', 'clip_sample_range', 'dynamic_thresholding_ratio', 'prediction_type', 'timestep_spacing', 'rescale_betas_zero_snr'} was not found in config. Values will be initialized to default values.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json: 100% 806/806 [00:00<00:00, 9.71MB/s]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/CompVis/stable-diffusion-v1-4/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/CompVis/stable-diffusion-v1-4/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/tokenizer/vocab.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/tokenizer%2Fvocab.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/tokenizer%2Fvocab.json "HTTP/1.1 200 OK"
# vocab.json: 1.06MB [00:00, 19.3MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/tokenizer/merges.txt "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/tokenizer%2Fmerges.txt "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/tokenizer%2Fmerges.txt "HTTP/1.1 200 OK"
# merges.txt: 525kB [00:00, 18.8MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/tokenizer/tokenizer.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/tokenizer/added_tokens.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/tokenizer/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/tokenizer%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/tokenizer%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# special_tokens_map.json: 100% 472/472 [00:00<00:00, 6.17MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/tokenizer/chat_template.jinja "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 592/592 [00:00<00:00, 7.05MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/text_encoder/adapter_config.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/text_encoder/model.safetensors "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/CompVis/stable-diffusion-v1-4/xet-read-token/133a221b8aa7292a167afc5127cb63fb5005638b "HTTP/1.1 200 OK"
# text_encoder/model.safetensors: 100% 492M/492M [00:02<00:00, 188MB/s]
# Loading weights: 100% 196/196 [00:00<00:00, 941.04it/s, Materializing param=text_model.final_layer_norm.weight]
# CLIPTextModel LOAD REPORT from: CompVis/stable-diffusion-v1-4
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/vae/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/vae%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/vae%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 551/551 [00:00<00:00, 6.86MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/133a221b8aa7292a167afc5127cb63fb5005638b/vae/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/133a221b8aa7292a167afc5127cb63fb5005638b/vae/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# vae/diffusion_pytorch_model.safetensors: 100% 335M/335M [00:01<00:00, 208MB/s]
# {'latents_mean', 'shift_factor', 'use_quant_conv', 'latents_std', 'use_post_quant_conv', 'force_upcast', 'mid_block_add_attention', 'norm_num_groups'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/unet%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/unet%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 743/743 [00:00<00:00, 9.44MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/133a221b8aa7292a167afc5127cb63fb5005638b/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/133a221b8aa7292a167afc5127cb63fb5005638b/unet/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# unet/diffusion_pytorch_model.safetensors: 100% 3.44G/3.44G [00:04<00:00, 746MB/s]
# {'time_embedding_type', 'addition_embed_type', 'timestep_post_act', 'mid_block_only_cross_attention', 'class_embed_type', 'addition_time_embed_dim', 'time_cond_proj_dim', 'attention_type', 'encoder_hid_dim_type', 'class_embeddings_concat', 'projection_class_embeddings_input_dim', 'num_attention_heads', 'transformer_layers_per_block', 'use_linear_projection', 'num_class_embeds', 'encoder_hid_dim', 'only_cross_attention', 'conv_out_kernel', 'reverse_transformer_layers_per_block', 'dropout', 'resnet_out_scale_factor', 'upcast_attention', 'cross_attention_norm', 'resnet_skip_time_act', 'resnet_time_scale_shift', 'addition_embed_type_num_heads', 'mid_block_type', 'time_embedding_act_fn', 'conv_in_kernel', 'dual_cross_attention', 'time_embedding_dim'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/unet%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/133a221b8aa7292a167afc5127cb63fb5005638b/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# {'time_embedding_type', 'addition_embed_type', 'timestep_post_act', 'mid_block_only_cross_attention', 'class_embed_type', 'addition_time_embed_dim', 'time_cond_proj_dim', 'attention_type', 'encoder_hid_dim_type', 'class_embeddings_concat', 'projection_class_embeddings_input_dim', 'num_attention_heads', 'transformer_layers_per_block', 'use_linear_projection', 'num_class_embeds', 'encoder_hid_dim', 'only_cross_attention', 'conv_out_kernel', 'reverse_transformer_layers_per_block', 'dropout', 'resnet_out_scale_factor', 'upcast_attention', 'cross_attention_norm', 'resnet_skip_time_act', 'resnet_time_scale_shift', 'addition_embed_type_num_heads', 'mid_block_type', 'time_embedding_act_fn', 'conv_in_kernel', 'dual_cross_attention', 'time_embedding_dim'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at CompVis/stable-diffusion-v1-4.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/imagefolder/imagefolder.py "HTTP/1.1 404 Not Found"
# Resolving data files: 100% 27001/27001 [00:00<00:00, 82496.46it/s]
# Downloading data: 100% 27001/27001 [00:00<00:00, 90124.11files/s]
# Generating train split: 26999 examples [00:00, 50993.15 examples/s]
# INFO:__main__:[RANK 0] ***** Running training *****
# INFO:__main__:[RANK 0]   Num examples = 26999
# INFO:__main__:[RANK 0]   Num Epochs = 9
# INFO:__main__:[RANK 0]   Instantaneous batch size per device = 8
# INFO:__main__:[RANK 0]   Total train batch size (w. parallel, distributed & accumulation) = 8
# INFO:__main__:[RANK 0]   Gradient Accumulation steps = 1
# INFO:__main__:[RANK 0]   Total optimization steps = 30000
# Steps:  33% 10000/30000 [55:54<1:51:49,  2.98it/s, lr=5e-6, step_loss=0.0637]INFO:accelerate.accelerator:[RANK 0] Saving current state to /content/sd14_celebahq/checkpoint-10000
# {'time_embedding_type', 'addition_embed_type', 'timestep_post_act', 'mid_block_only_cross_attention', 'class_embed_type', 'addition_time_embed_dim', 'time_cond_proj_dim', 'attention_type', 'encoder_hid_dim_type', 'class_embeddings_concat', 'projection_class_embeddings_input_dim', 'num_attention_heads', 'transformer_layers_per_block', 'use_linear_projection', 'num_class_embeds', 'encoder_hid_dim', 'only_cross_attention', 'conv_out_kernel', 'reverse_transformer_layers_per_block', 'dropout', 'resnet_out_scale_factor', 'upcast_attention', 'cross_attention_norm', 'resnet_skip_time_act', 'resnet_time_scale_shift', 'addition_embed_type_num_heads', 'mid_block_type', 'time_embedding_act_fn', 'conv_in_kernel', 'dual_cross_attention', 'time_embedding_dim'} was not found in config. Values will be initialized to default values.
# Configuration saved in /content/sd14_celebahq/checkpoint-10000/unet_ema/config.json
# Model weights saved in /content/sd14_celebahq/checkpoint-10000/unet_ema/diffusion_pytorch_model.safetensors
# Configuration saved in /content/sd14_celebahq/checkpoint-10000/unet/config.json
# Model weights saved in /content/sd14_celebahq/checkpoint-10000/unet/diffusion_pytorch_model.safetensors
# INFO:accelerate.checkpointing:[RANK 0] Optimizer state saved in /content/sd14_celebahq/checkpoint-10000/optimizer.bin
# INFO:accelerate.checkpointing:[RANK 0] Scheduler state saved in /content/sd14_celebahq/checkpoint-10000/scheduler.bin
# INFO:accelerate.checkpointing:[RANK 0] Sampler state for dataloader 0 saved in /content/sd14_celebahq/checkpoint-10000/sampler.bin
# INFO:accelerate.checkpointing:[RANK 0] Gradient scaler state saved in /content/sd14_celebahq/checkpoint-10000/scaler.pt
# INFO:accelerate.checkpointing:[RANK 0] Random states saved in /content/sd14_celebahq/checkpoint-10000/random_states_0.pkl
# INFO:__main__:[RANK 0] Saved state to /content/sd14_celebahq/checkpoint-10000
# Steps:  67% 20000/30000 [1:52:22<55:51,  2.98it/s, lr=5e-6, step_loss=0.0975]INFO:accelerate.accelerator:[RANK 0] Saving current state to /content/sd14_celebahq/checkpoint-20000
# {'time_embedding_type', 'addition_embed_type', 'timestep_post_act', 'mid_block_only_cross_attention', 'class_embed_type', 'addition_time_embed_dim', 'time_cond_proj_dim', 'attention_type', 'encoder_hid_dim_type', 'class_embeddings_concat', 'projection_class_embeddings_input_dim', 'num_attention_heads', 'transformer_layers_per_block', 'use_linear_projection', 'num_class_embeds', 'encoder_hid_dim', 'only_cross_attention', 'conv_out_kernel', 'reverse_transformer_layers_per_block', 'dropout', 'resnet_out_scale_factor', 'upcast_attention', 'cross_attention_norm', 'resnet_skip_time_act', 'resnet_time_scale_shift', 'addition_embed_type_num_heads', 'mid_block_type', 'time_embedding_act_fn', 'conv_in_kernel', 'dual_cross_attention', 'time_embedding_dim'} was not found in config. Values will be initialized to default values.
# Configuration saved in /content/sd14_celebahq/checkpoint-20000/unet_ema/config.json
# Model weights saved in /content/sd14_celebahq/checkpoint-20000/unet_ema/diffusion_pytorch_model.safetensors
# Configuration saved in /content/sd14_celebahq/checkpoint-20000/unet/config.json
# Model weights saved in /content/sd14_celebahq/checkpoint-20000/unet/diffusion_pytorch_model.safetensors
# INFO:accelerate.checkpointing:[RANK 0] Optimizer state saved in /content/sd14_celebahq/checkpoint-20000/optimizer.bin
# INFO:accelerate.checkpointing:[RANK 0] Scheduler state saved in /content/sd14_celebahq/checkpoint-20000/scheduler.bin
# INFO:accelerate.checkpointing:[RANK 0] Sampler state for dataloader 0 saved in /content/sd14_celebahq/checkpoint-20000/sampler.bin
# INFO:accelerate.checkpointing:[RANK 0] Gradient scaler state saved in /content/sd14_celebahq/checkpoint-20000/scaler.pt
# INFO:accelerate.checkpointing:[RANK 0] Random states saved in /content/sd14_celebahq/checkpoint-20000/random_states_0.pkl
# INFO:__main__:[RANK 0] Saved state to /content/sd14_celebahq/checkpoint-20000
# Steps: 100% 30000/30000 [2:48:50<00:00,  2.99it/s, lr=5e-6, step_loss=0.104]INFO:accelerate.accelerator:[RANK 0] Saving current state to /content/sd14_celebahq/checkpoint-30000
# {'time_embedding_type', 'addition_embed_type', 'timestep_post_act', 'mid_block_only_cross_attention', 'class_embed_type', 'addition_time_embed_dim', 'time_cond_proj_dim', 'attention_type', 'encoder_hid_dim_type', 'class_embeddings_concat', 'projection_class_embeddings_input_dim', 'num_attention_heads', 'transformer_layers_per_block', 'use_linear_projection', 'num_class_embeds', 'encoder_hid_dim', 'only_cross_attention', 'conv_out_kernel', 'reverse_transformer_layers_per_block', 'dropout', 'resnet_out_scale_factor', 'upcast_attention', 'cross_attention_norm', 'resnet_skip_time_act', 'resnet_time_scale_shift', 'addition_embed_type_num_heads', 'mid_block_type', 'time_embedding_act_fn', 'conv_in_kernel', 'dual_cross_attention', 'time_embedding_dim'} was not found in config. Values will be initialized to default values.
# Configuration saved in /content/sd14_celebahq/checkpoint-30000/unet_ema/config.json
# Model weights saved in /content/sd14_celebahq/checkpoint-30000/unet_ema/diffusion_pytorch_model.safetensors
# Configuration saved in /content/sd14_celebahq/checkpoint-30000/unet/config.json
# Model weights saved in /content/sd14_celebahq/checkpoint-30000/unet/diffusion_pytorch_model.safetensors
# INFO:accelerate.checkpointing:[RANK 0] Optimizer state saved in /content/sd14_celebahq/checkpoint-30000/optimizer.bin
# INFO:accelerate.checkpointing:[RANK 0] Scheduler state saved in /content/sd14_celebahq/checkpoint-30000/scheduler.bin
# INFO:accelerate.checkpointing:[RANK 0] Sampler state for dataloader 0 saved in /content/sd14_celebahq/checkpoint-30000/sampler.bin
# INFO:accelerate.checkpointing:[RANK 0] Gradient scaler state saved in /content/sd14_celebahq/checkpoint-30000/scaler.pt
# INFO:accelerate.checkpointing:[RANK 0] Random states saved in /content/sd14_celebahq/checkpoint-30000/random_states_0.pkl
# INFO:__main__:[RANK 0] Saved state to /content/sd14_celebahq/checkpoint-30000
# Steps: 100% 30000/30000 [2:49:24<00:00,  2.99it/s, lr=5e-6, step_loss=0.141]INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/CompVis/stable-diffusion-v1-4 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/main/model_index.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/model_index.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/model_index.json "HTTP/1.1 200 OK"
#
# model_index.json: 100% 541/541 [00:00<00:00, 6.45MB/s]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/CompVis/stable-diffusion-v1-4/revision/main "HTTP/1.1 200 OK"
#
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
#
# Fetching 10 files:   0% 0/10 [00:00<?, ?it/s]INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/133a221b8aa7292a167afc5127cb63fb5005638b/feature_extractor/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/133a221b8aa7292a167afc5127cb63fb5005638b/safety_checker/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/133a221b8aa7292a167afc5127cb63fb5005638b/scheduler/.ipynb_checkpoints/scheduler_config-checkpoint.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/CompVis/stable-diffusion-v1-4/resolve/133a221b8aa7292a167afc5127cb63fb5005638b/safety_checker/model.safetensors "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/feature_extractor%2Fpreprocessor_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/safety_checker%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/scheduler%2F.ipynb_checkpoints%2Fscheduler_config-checkpoint.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/feature_extractor%2Fpreprocessor_config.json "HTTP/1.1 200 OK"
#
# Downloading (incomplete total...):   0% 0.00/342 [00:00<?, ?B/s]
# Downloading (incomplete total...): 100% 342/342 [00:00<00:00, 1.91kB/s]
#
# Fetching 10 files:  10% 1/10 [00:00<00:01,  5.71it/s]INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/scheduler%2F.ipynb_checkpoints%2Fscheduler_config-checkpoint.json "HTTP/1.1 200 OK"
#
# Downloading (incomplete total...):  62% 342/551 [00:00<00:00, 1.91kB/s]INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/CompVis/stable-diffusion-v1-4/xet-read-token/133a221b8aa7292a167afc5127cb63fb5005638b "HTTP/1.1 200 OK"
#
# Downloading (incomplete total...):   0% 551/1.22G [00:00<176:23:38, 1.91kB/s]INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/CompVis/stable-diffusion-v1-4/133a221b8aa7292a167afc5127cb63fb5005638b/safety_checker%2Fconfig.json "HTTP/1.1 200 OK"
#
# Downloading (incomplete total...):   0% 5.11k/1.22G [00:00<24:30:03, 13.8kB/s]
# Downloading (incomplete total...):   6% 67.0M/1.22G [00:01<00:18, 63.6MB/s]
# Downloading (incomplete total...):  17% 201M/1.22G [00:01<00:05, 193MB/s]
# Downloading (incomplete total...):  22% 268M/1.22G [00:01<00:04, 226MB/s]
# Downloading (incomplete total...):  33% 402M/1.22G [00:01<00:02, 337MB/s]
# Downloading (incomplete total...):  44% 536M/1.22G [00:02<00:01, 425MB/s]
# Downloading (incomplete total...):  63% 768M/1.22G [00:02<00:00, 626MB/s]
# Downloading (incomplete total...):  77% 938M/1.22G [00:02<00:00, 689MB/s]
# Downloading (incomplete total...):  94% 1.14G/1.22G [00:02<00:00, 779MB/s]
#
# Fetching 10 files: 100% 10/10 [00:02<00:00,  3.55it/s]
#
# Download complete: : 1.22GB [00:02, 779MB/s]                              {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# Download complete: : 1.22GB [00:02, 428MB/s]
#
# Loading weights:   0% 0/396 [00:00<?, ?it/s]
# Loading weights:   0% 1/396 [00:00<00:00, 19508.39it/s, Materializing param=concept_embeds]
# Loading weights:   0% 1/396 [00:00<00:00, 9258.95it/s, Materializing param=concept_embeds]
# Loading weights:   1% 2/396 [00:00<00:00, 2211.02it/s, Materializing param=concept_embeds_weights]
# Loading weights:   1% 2/396 [00:00<00:00, 1640.64it/s, Materializing param=concept_embeds_weights]
# Loading weights:   1% 3/396 [00:00<00:00, 2014.56it/s, Materializing param=special_care_embeds]
# Loading weights:   1% 3/396 [00:00<00:00, 1754.69it/s, Materializing param=special_care_embeds]
# Loading weights:   1% 4/396 [00:00<00:00, 1998.95it/s, Materializing param=special_care_embeds_weights]
# Loading weights:   1% 4/396 [00:00<00:00, 1913.24it/s, Materializing param=special_care_embeds_weights]
# Loading weights:   1% 5/396 [00:00<00:00, 2222.74it/s, Materializing param=vision_model.vision_model.embeddings.class_embedding]
# Loading weights:   1% 5/396 [00:00<00:00, 2188.18it/s, Materializing param=vision_model.vision_model.embeddings.class_embedding]
# Loading weights:   2% 6/396 [00:00<00:00, 2358.34it/s, Materializing param=vision_model.vision_model.embeddings.patch_embedding.weight]
# Loading weights:   2% 6/396 [00:00<00:00, 1981.40it/s, Materializing param=vision_model.vision_model.embeddings.patch_embedding.weight]
# Loading weights:   2% 7/396 [00:00<00:00, 2132.34it/s, Materializing param=vision_model.vision_model.embeddings.position_embedding.weight]
# Loading weights:   2% 7/396 [00:00<00:00, 2003.56it/s, Materializing param=vision_model.vision_model.embeddings.position_embedding.weight]
# Loading weights:   2% 8/396 [00:00<00:00, 2165.78it/s, Materializing param=vision_model.vision_model.encoder.layers.0.layer_norm1.bias]
# Loading weights:   2% 8/396 [00:00<00:00, 1982.42it/s, Materializing param=vision_model.vision_model.encoder.layers.0.layer_norm1.bias]
# Loading weights:   2% 9/396 [00:00<00:00, 1961.08it/s, Materializing param=vision_model.vision_model.encoder.layers.0.layer_norm1.weight]
# Loading weights:   2% 9/396 [00:00<00:00, 1917.06it/s, Materializing param=vision_model.vision_model.encoder.layers.0.layer_norm1.weight]
# Loading weights:   3% 10/396 [00:00<00:00, 2047.30it/s, Materializing param=vision_model.vision_model.encoder.layers.0.layer_norm2.bias]
# Loading weights:   3% 10/396 [00:00<00:00, 2026.53it/s, Materializing param=vision_model.vision_model.encoder.layers.0.layer_norm2.bias]
# Loading weights:   3% 11/396 [00:00<00:00, 2199.95it/s, Materializing param=vision_model.vision_model.encoder.layers.0.layer_norm2.weight]
# Loading weights:   3% 11/396 [00:00<00:00, 2184.84it/s, Materializing param=vision_model.vision_model.encoder.layers.0.layer_norm2.weight]
# Loading weights:   3% 12/396 [00:00<00:00, 2311.23it/s, Materializing param=vision_model.vision_model.encoder.layers.0.mlp.fc1.bias]
# Loading weights:   3% 12/396 [00:00<00:00, 2296.15it/s, Materializing param=vision_model.vision_model.encoder.layers.0.mlp.fc1.bias]
# Loading weights:   3% 13/396 [00:00<00:00, 2434.74it/s, Materializing param=vision_model.vision_model.encoder.layers.0.mlp.fc1.weight]
# Loading weights:   3% 13/396 [00:00<00:00, 2329.47it/s, Materializing param=vision_model.vision_model.encoder.layers.0.mlp.fc1.weight]
# Loading weights:   4% 14/396 [00:00<00:00, 2414.78it/s, Materializing param=vision_model.vision_model.encoder.layers.0.mlp.fc2.bias]
# Loading weights:   4% 14/396 [00:00<00:00, 2383.42it/s, Materializing param=vision_model.vision_model.encoder.layers.0.mlp.fc2.bias]
# Loading weights:   4% 15/396 [00:00<00:00, 2474.42it/s, Materializing param=vision_model.vision_model.encoder.layers.0.mlp.fc2.weight]
# Loading weights:   4% 15/396 [00:00<00:00, 2460.68it/s, Materializing param=vision_model.vision_model.encoder.layers.0.mlp.fc2.weight]
# Loading weights:   4% 16/396 [00:00<00:00, 2567.97it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.k_proj.bias]
# Loading weights:   4% 16/396 [00:00<00:00, 2554.00it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.k_proj.bias]
# Loading weights:   4% 17/396 [00:00<00:00, 2658.19it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.k_proj.weight]
# Loading weights:   4% 17/396 [00:00<00:00, 2643.70it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.k_proj.weight]
# Loading weights:   5% 18/396 [00:00<00:00, 2764.26it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.out_proj.bias]
# Loading weights:   5% 18/396 [00:00<00:00, 2750.16it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.out_proj.bias]
# Loading weights:   5% 19/396 [00:00<00:00, 2857.57it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.out_proj.weight]
# Loading weights:   5% 19/396 [00:00<00:00, 2843.19it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.out_proj.weight]
# Loading weights:   5% 20/396 [00:00<00:00, 2936.06it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.q_proj.bias]
# Loading weights:   5% 20/396 [00:00<00:00, 2921.23it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.q_proj.bias]
# Loading weights:   5% 21/396 [00:00<00:00, 3015.63it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.q_proj.weight]
# Loading weights:   5% 21/396 [00:00<00:00, 3001.55it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.q_proj.weight]
# Loading weights:   6% 22/396 [00:00<00:00, 3116.55it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.v_proj.bias]
# Loading weights:   6% 22/396 [00:00<00:00, 3102.19it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.v_proj.bias]
# Loading weights:   6% 23/396 [00:00<00:00, 3199.21it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.v_proj.weight]
# Loading weights:   6% 23/396 [00:00<00:00, 3184.64it/s, Materializing param=vision_model.vision_model.encoder.layers.0.self_attn.v_proj.weight]
# Loading weights:   6% 24/396 [00:00<00:00, 3289.44it/s, Materializing param=vision_model.vision_model.encoder.layers.1.layer_norm1.bias]
# Loading weights:   6% 24/396 [00:00<00:00, 3274.88it/s, Materializing param=vision_model.vision_model.encoder.layers.1.layer_norm1.bias]
# Loading weights:   6% 25/396 [00:00<00:00, 3333.15it/s, Materializing param=vision_model.vision_model.encoder.layers.1.layer_norm1.weight]
# Loading weights:   6% 25/396 [00:00<00:00, 3317.44it/s, Materializing param=vision_model.vision_model.encoder.layers.1.layer_norm1.weight]
# Loading weights:   7% 26/396 [00:00<00:00, 3421.67it/s, Materializing param=vision_model.vision_model.encoder.layers.1.layer_norm2.bias]
# Loading weights:   7% 26/396 [00:00<00:00, 3407.34it/s, Materializing param=vision_model.vision_model.encoder.layers.1.layer_norm2.bias]
# Loading weights:   7% 27/396 [00:00<00:00, 3505.10it/s, Materializing param=vision_model.vision_model.encoder.layers.1.layer_norm2.weight]
# Loading weights:   7% 27/396 [00:00<00:00, 3490.73it/s, Materializing param=vision_model.vision_model.encoder.layers.1.layer_norm2.weight]
# Loading weights:   7% 28/396 [00:00<00:00, 3567.45it/s, Materializing param=vision_model.vision_model.encoder.layers.1.mlp.fc1.bias]
# Loading weights:   7% 28/396 [00:00<00:00, 3552.56it/s, Materializing param=vision_model.vision_model.encoder.layers.1.mlp.fc1.bias]
# Loading weights:   7% 29/396 [00:00<00:00, 3592.18it/s, Materializing param=vision_model.vision_model.encoder.layers.1.mlp.fc1.weight]
# Loading weights:   7% 29/396 [00:00<00:00, 3577.07it/s, Materializing param=vision_model.vision_model.encoder.layers.1.mlp.fc1.weight]
# Loading weights:   8% 30/396 [00:00<00:00, 3627.35it/s, Materializing param=vision_model.vision_model.encoder.layers.1.mlp.fc2.bias]
# Loading weights:   8% 30/396 [00:00<00:00, 3612.87it/s, Materializing param=vision_model.vision_model.encoder.layers.1.mlp.fc2.bias]
# Loading weights:   8% 31/396 [00:00<00:00, 3701.63it/s, Materializing param=vision_model.vision_model.encoder.layers.1.mlp.fc2.weight]
# Loading weights:   8% 31/396 [00:00<00:00, 3687.25it/s, Materializing param=vision_model.vision_model.encoder.layers.1.mlp.fc2.weight]
# Loading weights:   8% 32/396 [00:00<00:00, 3693.69it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.k_proj.bias]
# Loading weights:   8% 32/396 [00:00<00:00, 3679.42it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.k_proj.bias]
# Loading weights:   8% 33/396 [00:00<00:00, 3734.71it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.k_proj.weight]
# Loading weights:   8% 33/396 [00:00<00:00, 3720.85it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.k_proj.weight]
# Loading weights:   9% 34/396 [00:00<00:00, 3802.43it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.out_proj.bias]
# Loading weights:   9% 34/396 [00:00<00:00, 3788.19it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.out_proj.bias]
# Loading weights:   9% 35/396 [00:00<00:00, 3835.22it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.out_proj.weight]
# Loading weights:   9% 35/396 [00:00<00:00, 3821.04it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.out_proj.weight]
# Loading weights:   9% 36/396 [00:00<00:00, 3899.76it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.q_proj.bias]
# Loading weights:   9% 36/396 [00:00<00:00, 3885.91it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.q_proj.bias]
# Loading weights:   9% 37/396 [00:00<00:00, 3960.73it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.q_proj.weight]
# Loading weights:   9% 37/396 [00:00<00:00, 3943.72it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.q_proj.weight]
# Loading weights:  10% 38/396 [00:00<00:00, 4016.32it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.v_proj.bias]
# Loading weights:  10% 38/396 [00:00<00:00, 4002.60it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.v_proj.bias]
# Loading weights:  10% 39/396 [00:00<00:00, 4044.05it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.v_proj.weight]
# Loading weights:  10% 39/396 [00:00<00:00, 4030.20it/s, Materializing param=vision_model.vision_model.encoder.layers.1.self_attn.v_proj.weight]
# Loading weights:  10% 40/396 [00:00<00:00, 4080.26it/s, Materializing param=vision_model.vision_model.encoder.layers.2.layer_norm1.bias]
# Loading weights:  10% 40/396 [00:00<00:00, 4066.51it/s, Materializing param=vision_model.vision_model.encoder.layers.2.layer_norm1.bias]
# Loading weights:  10% 41/396 [00:00<00:00, 4141.97it/s, Materializing param=vision_model.vision_model.encoder.layers.2.layer_norm1.weight]
# Loading weights:  10% 41/396 [00:00<00:00, 4128.65it/s, Materializing param=vision_model.vision_model.encoder.layers.2.layer_norm1.weight]
# Loading weights:  11% 42/396 [00:00<00:00, 4151.01it/s, Materializing param=vision_model.vision_model.encoder.layers.2.layer_norm2.bias]
# Loading weights:  11% 42/396 [00:00<00:00, 4137.56it/s, Materializing param=vision_model.vision_model.encoder.layers.2.layer_norm2.bias]
# Loading weights:  11% 43/396 [00:00<00:00, 4192.26it/s, Materializing param=vision_model.vision_model.encoder.layers.2.layer_norm2.weight]
# Loading weights:  11% 43/396 [00:00<00:00, 4179.24it/s, Materializing param=vision_model.vision_model.encoder.layers.2.layer_norm2.weight]
# Loading weights:  11% 44/396 [00:00<00:00, 4240.95it/s, Materializing param=vision_model.vision_model.encoder.layers.2.mlp.fc1.bias]
# Loading weights:  11% 44/396 [00:00<00:00, 4227.45it/s, Materializing param=vision_model.vision_model.encoder.layers.2.mlp.fc1.bias]
# Loading weights:  11% 45/396 [00:00<00:00, 4269.25it/s, Materializing param=vision_model.vision_model.encoder.layers.2.mlp.fc1.weight]
# Loading weights:  11% 45/396 [00:00<00:00, 4255.87it/s, Materializing param=vision_model.vision_model.encoder.layers.2.mlp.fc1.weight]
# Loading weights:  12% 46/396 [00:00<00:00, 4260.15it/s, Materializing param=vision_model.vision_model.encoder.layers.2.mlp.fc2.bias]
# Loading weights:  12% 46/396 [00:00<00:00, 4247.02it/s, Materializing param=vision_model.vision_model.encoder.layers.2.mlp.fc2.bias]
# Loading weights:  12% 47/396 [00:00<00:00, 4292.86it/s, Materializing param=vision_model.vision_model.encoder.layers.2.mlp.fc2.weight]
# Loading weights:  12% 47/396 [00:00<00:00, 4279.81it/s, Materializing param=vision_model.vision_model.encoder.layers.2.mlp.fc2.weight]
# Loading weights:  12% 48/396 [00:00<00:00, 4219.53it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.k_proj.bias]
# Loading weights:  12% 48/396 [00:00<00:00, 4206.66it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.k_proj.bias]
# Loading weights:  12% 49/396 [00:00<00:00, 4269.85it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.k_proj.weight]
# Loading weights:  12% 49/396 [00:00<00:00, 4257.47it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.k_proj.weight]
# Loading weights:  13% 50/396 [00:00<00:00, 4284.45it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.out_proj.bias]
# Loading weights:  13% 50/396 [00:00<00:00, 4272.06it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.out_proj.bias]
# Loading weights:  13% 51/396 [00:00<00:00, 4302.72it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.out_proj.weight]
# Loading weights:  13% 51/396 [00:00<00:00, 4290.89it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.out_proj.weight]
# Loading weights:  13% 52/396 [00:00<00:00, 4351.37it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.q_proj.bias]
# Loading weights:  13% 52/396 [00:00<00:00, 4339.42it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.q_proj.bias]
# Loading weights:  13% 53/396 [00:00<00:00, 4375.34it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.q_proj.weight]
# Loading weights:  13% 53/396 [00:00<00:00, 4363.06it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.q_proj.weight]
# Loading weights:  14% 54/396 [00:00<00:00, 4423.16it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.v_proj.bias]
# Loading weights:  14% 54/396 [00:00<00:00, 4411.36it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.v_proj.bias]
# Loading weights:  14% 55/396 [00:00<00:00, 4441.66it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.v_proj.weight]
# Loading weights:  14% 55/396 [00:00<00:00, 4429.72it/s, Materializing param=vision_model.vision_model.encoder.layers.2.self_attn.v_proj.weight]
# Loading weights:  14% 56/396 [00:00<00:00, 4439.76it/s, Materializing param=vision_model.vision_model.encoder.layers.3.layer_norm1.bias]
# Loading weights:  14% 56/396 [00:00<00:00, 4428.12it/s, Materializing param=vision_model.vision_model.encoder.layers.3.layer_norm1.bias]
# Loading weights:  14% 57/396 [00:00<00:00, 4483.87it/s, Materializing param=vision_model.vision_model.encoder.layers.3.layer_norm1.weight]
# Loading weights:  14% 57/396 [00:00<00:00, 4472.29it/s, Materializing param=vision_model.vision_model.encoder.layers.3.layer_norm1.weight]
# Loading weights:  15% 58/396 [00:00<00:00, 4505.99it/s, Materializing param=vision_model.vision_model.encoder.layers.3.layer_norm2.bias]
# Loading weights:  15% 58/396 [00:00<00:00, 4494.09it/s, Materializing param=vision_model.vision_model.encoder.layers.3.layer_norm2.bias]
# Loading weights:  15% 59/396 [00:00<00:00, 4521.95it/s, Materializing param=vision_model.vision_model.encoder.layers.3.layer_norm2.weight]
# Loading weights:  15% 59/396 [00:00<00:00, 2091.04it/s, Materializing param=vision_model.vision_model.encoder.layers.3.layer_norm2.weight]
# Loading weights:  15% 60/396 [00:00<00:00, 2121.60it/s, Materializing param=vision_model.vision_model.encoder.layers.3.mlp.fc1.bias]
# Loading weights:  15% 60/396 [00:00<00:00, 2119.17it/s, Materializing param=vision_model.vision_model.encoder.layers.3.mlp.fc1.bias]
# Loading weights:  15% 61/396 [00:00<00:00, 2149.88it/s, Materializing param=vision_model.vision_model.encoder.layers.3.mlp.fc1.weight]
# Loading weights:  15% 61/396 [00:00<00:00, 2147.64it/s, Materializing param=vision_model.vision_model.encoder.layers.3.mlp.fc1.weight]
# Loading weights:  16% 62/396 [00:00<00:00, 2179.04it/s, Materializing param=vision_model.vision_model.encoder.layers.3.mlp.fc2.bias]
# Loading weights:  16% 62/396 [00:00<00:00, 2176.80it/s, Materializing param=vision_model.vision_model.encoder.layers.3.mlp.fc2.bias]
# Loading weights:  16% 63/396 [00:00<00:00, 2208.30it/s, Materializing param=vision_model.vision_model.encoder.layers.3.mlp.fc2.weight]
# Loading weights:  16% 63/396 [00:00<00:00, 2206.05it/s, Materializing param=vision_model.vision_model.encoder.layers.3.mlp.fc2.weight]
# Loading weights:  16% 64/396 [00:00<00:00, 2237.28it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.k_proj.bias]
# Loading weights:  16% 64/396 [00:00<00:00, 2234.93it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.k_proj.bias]
# Loading weights:  16% 65/396 [00:00<00:00, 2266.10it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.k_proj.weight]
# Loading weights:  16% 65/396 [00:00<00:00, 2263.77it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.k_proj.weight]
# Loading weights:  17% 66/396 [00:00<00:00, 2294.82it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.out_proj.bias]
# Loading weights:  17% 66/396 [00:00<00:00, 2292.52it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.out_proj.bias]
# Loading weights:  17% 67/396 [00:00<00:00, 2323.41it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.out_proj.weight]
# Loading weights:  17% 67/396 [00:00<00:00, 2321.08it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.out_proj.weight]
# Loading weights:  17% 68/396 [00:00<00:00, 2351.82it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.q_proj.bias]
# Loading weights:  17% 68/396 [00:00<00:00, 2349.44it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.q_proj.bias]
# Loading weights:  17% 69/396 [00:00<00:00, 2380.17it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.q_proj.weight]
# Loading weights:  17% 69/396 [00:00<00:00, 2377.80it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.q_proj.weight]
# Loading weights:  18% 70/396 [00:00<00:00, 2408.29it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.v_proj.bias]
# Loading weights:  18% 70/396 [00:00<00:00, 2405.78it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.v_proj.bias]
# Loading weights:  18% 71/396 [00:00<00:00, 2436.04it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.v_proj.weight]
# Loading weights:  18% 71/396 [00:00<00:00, 2433.51it/s, Materializing param=vision_model.vision_model.encoder.layers.3.self_attn.v_proj.weight]
# Loading weights:  18% 72/396 [00:00<00:00, 2463.80it/s, Materializing param=vision_model.vision_model.encoder.layers.4.layer_norm1.bias]
# Loading weights:  18% 72/396 [00:00<00:00, 2461.31it/s, Materializing param=vision_model.vision_model.encoder.layers.4.layer_norm1.bias]
# Loading weights:  18% 73/396 [00:00<00:00, 2491.41it/s, Materializing param=vision_model.vision_model.encoder.layers.4.layer_norm1.weight]
# Loading weights:  18% 73/396 [00:00<00:00, 2488.90it/s, Materializing param=vision_model.vision_model.encoder.layers.4.layer_norm1.weight]
# Loading weights:  19% 74/396 [00:00<00:00, 2518.02it/s, Materializing param=vision_model.vision_model.encoder.layers.4.layer_norm2.bias]
# Loading weights:  19% 74/396 [00:00<00:00, 2515.49it/s, Materializing param=vision_model.vision_model.encoder.layers.4.layer_norm2.bias]
# Loading weights:  19% 75/396 [00:00<00:00, 2545.36it/s, Materializing param=vision_model.vision_model.encoder.layers.4.layer_norm2.weight]
# Loading weights:  19% 75/396 [00:00<00:00, 2542.80it/s, Materializing param=vision_model.vision_model.encoder.layers.4.layer_norm2.weight]
# Loading weights:  19% 76/396 [00:00<00:00, 2572.76it/s, Materializing param=vision_model.vision_model.encoder.layers.4.mlp.fc1.bias]
# Loading weights:  19% 76/396 [00:00<00:00, 2570.27it/s, Materializing param=vision_model.vision_model.encoder.layers.4.mlp.fc1.bias]
# Loading weights:  19% 77/396 [00:00<00:00, 2599.98it/s, Materializing param=vision_model.vision_model.encoder.layers.4.mlp.fc1.weight]
# Loading weights:  19% 77/396 [00:00<00:00, 2597.41it/s, Materializing param=vision_model.vision_model.encoder.layers.4.mlp.fc1.weight]
# Loading weights:  20% 78/396 [00:00<00:00, 2627.04it/s, Materializing param=vision_model.vision_model.encoder.layers.4.mlp.fc2.bias]
# Loading weights:  20% 78/396 [00:00<00:00, 2624.49it/s, Materializing param=vision_model.vision_model.encoder.layers.4.mlp.fc2.bias]
# Loading weights:  20% 79/396 [00:00<00:00, 2653.92it/s, Materializing param=vision_model.vision_model.encoder.layers.4.mlp.fc2.weight]
# Loading weights:  20% 79/396 [00:00<00:00, 2651.31it/s, Materializing param=vision_model.vision_model.encoder.layers.4.mlp.fc2.weight]
# Loading weights:  20% 80/396 [00:00<00:00, 2680.58it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.k_proj.bias]
# Loading weights:  20% 80/396 [00:00<00:00, 2677.88it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.k_proj.bias]
# Loading weights:  20% 81/396 [00:00<00:00, 2707.12it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.k_proj.weight]
# Loading weights:  20% 81/396 [00:00<00:00, 2704.39it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.k_proj.weight]
# Loading weights:  21% 82/396 [00:00<00:00, 2733.57it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.out_proj.bias]
# Loading weights:  21% 82/396 [00:00<00:00, 2730.95it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.out_proj.bias]
# Loading weights:  21% 83/396 [00:00<00:00, 2759.89it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.out_proj.weight]
# Loading weights:  21% 83/396 [00:00<00:00, 2757.18it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.out_proj.weight]
# Loading weights:  21% 84/396 [00:00<00:00, 2786.03it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.q_proj.bias]
# Loading weights:  21% 84/396 [00:00<00:00, 2783.26it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.q_proj.bias]
# Loading weights:  21% 85/396 [00:00<00:00, 2812.08it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.q_proj.weight]
# Loading weights:  21% 85/396 [00:00<00:00, 2809.36it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.q_proj.weight]
# Loading weights:  22% 86/396 [00:00<00:00, 2837.98it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.v_proj.bias]
# Loading weights:  22% 86/396 [00:00<00:00, 2835.28it/s, Materializing param=vision_model.vision_model.encoder.layers.4.self_attn.v_proj.bias]
# ...
# Loading weights:  87% 346/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.layer_norm2.bias]
# Loading weights:  87% 346/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.layer_norm2.bias]
# Loading weights:  88% 347/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.layer_norm2.weight]
# Loading weights:  88% 347/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.layer_norm2.weight]
# Loading weights:  88% 348/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc1.bias]
# Loading weights:  88% 348/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc1.bias]
# Loading weights:  88% 349/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc1.weight]
# Loading weights:  88% 349/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc1.weight]
# Loading weights:  88% 350/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc2.bias]
# Loading weights:  88% 350/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc2.bias]
# Loading weights:  89% 351/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc2.weight]
# Loading weights:  89% 351/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.mlp.fc2.weight]
# Loading weights:  89% 352/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.k_proj.bias]
# Loading weights:  89% 352/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.k_proj.bias]
# Loading weights:  89% 353/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.k_proj.weight]
# Loading weights:  89% 353/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.k_proj.weight]
# Loading weights:  89% 354/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.out_proj.bias]
# Loading weights:  89% 354/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.out_proj.bias]
# Loading weights:  90% 355/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.out_proj.weight]
# Loading weights:  90% 355/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.out_proj.weight]
# Loading weights:  90% 356/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.q_proj.bias]
# Loading weights:  90% 356/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.q_proj.bias]
# Loading weights:  90% 357/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.q_proj.weight]
# Loading weights:  90% 357/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.q_proj.weight]
# Loading weights:  90% 358/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.v_proj.bias]
# Loading weights:  90% 358/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.v_proj.bias]
# Loading weights:  91% 359/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.v_proj.weight]
# Loading weights:  91% 359/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.21.self_attn.v_proj.weight]
# Loading weights:  91% 360/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm1.bias]
# Loading weights:  91% 360/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm1.bias]
# Loading weights:  91% 361/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm1.weight]
# Loading weights:  91% 361/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm1.weight]
# Loading weights:  91% 362/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm2.bias]
# Loading weights:  91% 362/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm2.bias]
# Loading weights:  92% 363/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm2.weight]
# Loading weights:  92% 363/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.layer_norm2.weight]
# Loading weights:  92% 364/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc1.bias]
# Loading weights:  92% 364/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc1.bias]
# Loading weights:  92% 365/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc1.weight]
# Loading weights:  92% 365/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc1.weight]
# Loading weights:  92% 366/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc2.bias]
# Loading weights:  92% 366/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc2.bias]
# Loading weights:  93% 367/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc2.weight]
# Loading weights:  93% 367/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.mlp.fc2.weight]
# Loading weights:  93% 368/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.k_proj.bias]
# Loading weights:  93% 368/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.k_proj.bias]
# Loading weights:  93% 369/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.k_proj.weight]
# Loading weights:  93% 369/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.k_proj.weight]
# Loading weights:  93% 370/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.out_proj.bias]
# Loading weights:  93% 370/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.out_proj.bias]
# Loading weights:  94% 371/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.out_proj.weight]
# Loading weights:  94% 371/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.out_proj.weight]
# Loading weights:  94% 372/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.q_proj.bias]
# Loading weights:  94% 372/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.q_proj.bias]
# Loading weights:  94% 373/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.q_proj.weight]
# Loading weights:  94% 373/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.q_proj.weight]
# Loading weights:  94% 374/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.v_proj.bias]
# Loading weights:  94% 374/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.v_proj.bias]
# Loading weights:  95% 375/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.v_proj.weight]
# Loading weights:  95% 375/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.22.self_attn.v_proj.weight]
# Loading weights:  95% 376/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm1.bias]
# Loading weights:  95% 376/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm1.bias]
# Loading weights:  95% 377/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm1.weight]
# Loading weights:  95% 377/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm1.weight]
# Loading weights:  95% 378/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm2.bias]
# Loading weights:  95% 378/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm2.bias]
# Loading weights:  96% 379/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm2.weight]
# Loading weights:  96% 379/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.layer_norm2.weight]
# Loading weights:  96% 380/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.bias]
# Loading weights:  96% 380/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.bias]
# Loading weights:  96% 381/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.weight]
# Loading weights:  96% 381/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc1.weight]
# Loading weights:  96% 382/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc2.bias]
# Loading weights:  96% 382/396 [00:00<00:00, 659.02it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc2.bias]
# Loading weights:  97% 383/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc2.bias]
# Loading weights:  97% 383/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc2.weight]
# Loading weights:  97% 383/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.mlp.fc2.weight]
# Loading weights:  97% 384/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.k_proj.bias]
# Loading weights:  97% 384/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.k_proj.bias]
# Loading weights:  97% 385/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.k_proj.weight]
# Loading weights:  97% 385/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.k_proj.weight]
# Loading weights:  97% 386/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.out_proj.bias]
# Loading weights:  97% 386/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.out_proj.bias]
# Loading weights:  98% 387/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.out_proj.weight]
# Loading weights:  98% 387/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.out_proj.weight]
# Loading weights:  98% 388/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.q_proj.bias]
# Loading weights:  98% 388/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.q_proj.bias]
# Loading weights:  98% 389/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.q_proj.weight]
# Loading weights:  98% 389/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.q_proj.weight]
# Loading weights:  98% 390/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.v_proj.bias]
# Loading weights:  98% 390/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.v_proj.bias]
# Loading weights:  99% 391/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.v_proj.weight]
# Loading weights:  99% 391/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.encoder.layers.23.self_attn.v_proj.weight]
# Loading weights:  99% 392/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.post_layernorm.bias]
# Loading weights:  99% 392/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.post_layernorm.bias]
# Loading weights:  99% 393/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.post_layernorm.weight]
# Loading weights:  99% 393/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.post_layernorm.weight]
# Loading weights:  99% 394/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.pre_layrnorm.bias]
# Loading weights:  99% 394/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.pre_layrnorm.bias]
# Loading weights: 100% 395/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.pre_layrnorm.weight]
# Loading weights: 100% 395/396 [00:00<00:00, 677.78it/s, Materializing param=vision_model.vision_model.pre_layrnorm.weight]
# Loading weights: 100% 396/396 [00:00<00:00, 677.78it/s, Materializing param=visual_projection.weight]
# Loading weights: 100% 396/396 [00:00<00:00, 744.00it/s, Materializing param=visual_projection.weight]
# StableDiffusionSafetyChecker LOAD REPORT from: /root/.cache/huggingface/hub/models--CompVis--stable-diffusion-v1-4/snapshots/133a221b8aa7292a167afc5127cb63fb5005638b/safety_checker
# Key                                               | Status     |  |
# --------------------------------------------------+------------+--+-
# vision_model.vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
#
# Loading pipeline components...:  43% 3/7 [00:00<00:00,  5.10it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 11.28it/s]
# Configuration saved in /content/sd14_celebahq/vae/config.json
# Model weights saved in /content/sd14_celebahq/vae/diffusion_pytorch_model.safetensors
#
# Writing model shards:   0% 0/1 [00:00<?, ?it/s]
# Writing model shards: 100% 1/1 [00:00<00:00,  7.47it/s]
# Configuration saved in /content/sd14_celebahq/unet/config.json
# Model weights saved in /content/sd14_celebahq/unet/diffusion_pytorch_model.safetensors
# Configuration saved in /content/sd14_celebahq/scheduler/scheduler_config.json
#
# Writing model shards:   0% 0/1 [00:00<?, ?it/s]
# Writing model shards: 100% 1/1 [00:03<00:00,  3.42s/it]
# Configuration saved in /content/sd14_celebahq/model_index.json
# Steps: 100% 30000/30000 [2:49:42<00:00,  2.95it/s, lr=5e-6, step_loss=0.141]

# %%
from tensorboard.backend.event_processing import event_accumulator
import matplotlib.pyplot as plt

log_dir = "/content/sd14_celebahq/logs/text2image-fine-tune"

ea = event_accumulator.EventAccumulator(log_dir)
ea.Reload()

print("Available tags:", ea.Tags())

loss_tag = "train_loss"

losses = [x.value for x in ea.Scalars(loss_tag)]
steps  = [x.step for x in ea.Scalars(loss_tag)]

plt.plot(steps, losses)
plt.title("Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.show()
# Out:
# Available tags: {'images': [], 'audio': [], 'histograms': [], 'scalars': ['train_loss'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
import numpy as np
import matplotlib.pyplot as plt

window = 1000  # smoothing window

smoothed = np.convolve(losses, np.ones(window)/window, mode='valid')

plt.plot(steps[:len(smoothed)], smoothed)
plt.title("Smoothed Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.show()

# %%
import numpy as np

loss_tag = "train_loss"
losses = [x.value for x in ea.Scalars(loss_tag)]

print("First 2k avg:", np.mean(losses[:2000]))
print("Last  2k avg:", np.mean(losses[-2000:]))

print("Std first:", np.std(losses[:2000]))
print("Std last :", np.std(losses[-2000:]))
# Out:
# First 2k avg: 0.14651042742840945
# Last  2k avg: 0.14108207830134778
# Std first: 0.06201433022395422
# Std last : 0.06268005926505005

# %%
import shutil
from google.colab import files

MODEL_DIR = "/content/sd14_celebahq"
ZIP_PATH = "/content/final_sd14_model.zip"

# Remove checkpoints (keep only final weights)
import os
for item in os.listdir(MODEL_DIR):
    if item.startswith("checkpoint"):
        shutil.rmtree(os.path.join(MODEL_DIR, item))

# Zip the final model
shutil.make_archive("/content/final_sd14_model", 'zip', MODEL_DIR)

# Download
files.download(ZIP_PATH)

# %%
# ============================================================
# CLEANUP BEFORE GENERATION
# ============================================================

import os
import gc
import torch
import shutil

GEN_DIR = "/content/generated_SDv1-5"

# ------------------------------------------------------------
# DELETE GENERATED FOLDER
# ------------------------------------------------------------

if os.path.exists(GEN_DIR):

    shutil.rmtree(GEN_DIR)

    print("Deleted:", GEN_DIR)

# ------------------------------------------------------------
# RECREATE EMPTY FOLDER
# ------------------------------------------------------------

os.makedirs(GEN_DIR, exist_ok=True)

print("Created clean folder:", GEN_DIR)

# ------------------------------------------------------------
# CLEAR PIPELINE FROM MEMORY
# ------------------------------------------------------------

try:
    del pipe
    print("Deleted pipeline object")

except:
    pass

# ------------------------------------------------------------
# PYTORCH CLEANUP
# ------------------------------------------------------------

gc.collect()

torch.cuda.empty_cache()

torch.cuda.ipc_collect()

# ------------------------------------------------------------
# VRAM STATUS
# ------------------------------------------------------------

print("\nCUDA memory cleared")

print(
    "Allocated:",
    round(torch.cuda.memory_allocated() / 1024**3, 2),
    "GB"
)

print(
    "Reserved:",
    round(torch.cuda.memory_reserved() / 1024**3, 2),
    "GB"
)
# Out:
# Created clean folder: /content/generated_SDv1-5
# Deleted pipeline object
#
# CUDA memory cleared
# Allocated: 2.63 GB
# Reserved: 3.1 GB

# %%
PROMPTS = [

    "a face with 5_o_Clock_Shadow, Male, Mouth_Slightly_Open, Young",

    "a face with Bags_Under_Eyes, Brown_Hair, Big_Nose, Male, Straight_Hair",

    "a face with Black_Hair, Bangs, Smiling, Heavy_Makeup, Wearing_Lipstick",

    "a face with Blond_Hair, Big_Lips, Pale_Skin, Straight_Hair",

    "a face with Brown_Hair, High_Cheekbones, Smiling, Wearing_Lipstick",

    "a face with Black_Hair, Bushy_Eyebrows, Oval_Face, Heavy_Makeup",

    "a face with Big_Nose, Brown_Hair, Male, Pointy_Nose",

    "a face with Bangs, Black_Hair, Pale_Skin, Wearing_Earrings",

    "a face with Wavy_Hair, Smiling, High_Cheekbones, Wearing_Necklace",

    "a face with Blond_Hair, Big_Lips, Smiling, Wearing_Earrings"
]

print("Total prompts:", len(PROMPTS))

for i, p in enumerate(PROMPTS):
    print(f"\nPrompt {i+1}:")
    print(p)
# Out:
# Total prompts: 10
#
# Prompt 1:
# a face with 5_o_Clock_Shadow, Male, Mouth_Slightly_Open, Young
#
# Prompt 2:
# a face with Bags_Under_Eyes, Brown_Hair, Big_Nose, Male, Straight_Hair
#
# Prompt 3:
# a face with Black_Hair, Bangs, Smiling, Heavy_Makeup, Wearing_Lipstick
#
# Prompt 4:
# a face with Blond_Hair, Big_Lips, Pale_Skin, Straight_Hair
#
# Prompt 5:
# a face with Brown_Hair, High_Cheekbones, Smiling, Wearing_Lipstick
#
# Prompt 6:
# a face with Black_Hair, Bushy_Eyebrows, Oval_Face, Heavy_Makeup
#
# Prompt 7:
# a face with Big_Nose, Brown_Hair, Male, Pointy_Nose
#
# Prompt 8:
# a face with Bangs, Black_Hair, Pale_Skin, Wearing_Earrings
#
# Prompt 9:
# a face with Wavy_Hair, Smiling, High_Cheekbones, Wearing_Necklace
#
# Prompt 10:
# a face with Blond_Hair, Big_Lips, Smiling, Wearing_Earrings

# %%
os.makedirs("/content/generated_SDv1-4", exist_ok=True)

rows = []

for i in range(300):

    rows.append({
        "image": f"{i:03d}.png",
        "prompt": PROMPTS[i % len(PROMPTS)]
    })

df = pd.DataFrame(rows)

df.to_csv(
    "/content/generated_SDv1-4/prompts.csv",
    index=False
)

print(df.head())
print("\nSaved prompts.csv")
# Out:
#      image                                             prompt
# 0  000.png  a face with 5_o_Clock_Shadow, Male, Mouth_Slig...
# 1  001.png  a face with Bags_Under_Eyes, Brown_Hair, Big_N...
# 2  002.png  a face with Black_Hair, Bangs, Smiling, Heavy_...
# 3  003.png  a face with Blond_Hair, Big_Lips, Pale_Skin, S...
# 4  004.png  a face with Brown_Hair, High_Cheekbones, Smili...
#
# Saved prompts.csv

# %%
# %cd /content
# Out:
# /content

# %%
import sys
import os
import torch
import pandas as pd

from tqdm.auto import tqdm

sys.path.append("/content/diffusers/src")

from diffusers import (
    StableDiffusionPipeline,
    DPMSolverMultistepScheduler
)

MODEL_PATH = "/content/sd14_celebahq"
GEN_DIR = "/content/generated_SDv1-4"

os.makedirs(GEN_DIR, exist_ok=True)

# Clear old images
for f in os.listdir(GEN_DIR):
    os.remove(os.path.join(GEN_DIR, f))

pipe = StableDiffusionPipeline.from_pretrained(
    MODEL_PATH,
    torch_dtype=torch.float16
).to("cuda")

pipe.scheduler = DPMSolverMultistepScheduler.from_config(
    pipe.scheduler.config
)

pipe.safety_checker = None
pipe.set_progress_bar_config(disable=False)

num_images = 300
batch_size = 4

prompt_log = []

idx = 0

pbar = tqdm(
    total=num_images,
    desc="Generating Images",
    unit="img"
)

while idx < num_images:

    cur_bs = min(batch_size, num_images - idx)

    batch_prompts = [
        PROMPTS[(idx + j) % len(PROMPTS)]
        for j in range(cur_bs)
    ]

    generators = [
        torch.Generator(device="cuda").manual_seed(idx + j)
        for j in range(cur_bs)
    ]

    with torch.no_grad():

        outputs = pipe(
            prompt=batch_prompts,
            height=512,
            width=512,
            num_inference_steps=50,
            guidance_scale=5.0,
            generator=generators
        )

    images = outputs.images

    for j, img in enumerate(images):

        img_name = f"{idx:03d}.png"

        img.save(os.path.join(GEN_DIR, img_name))

        prompt_log.append({
            "image": img_name,
            "prompt": batch_prompts[j]
        })

        idx += 1
        pbar.update(1)

pbar.close()

pd.DataFrame(prompt_log).to_csv(
    os.path.join(GEN_DIR, "prompts.csv"),
    index=False
)

print("\nDone.")
print("Generated images:", len(os.listdir(GEN_DIR)) - 1)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# Generating Images:   0%|          | 0/300 [00:00<?, ?img/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Done.
# Generated images: 300

# %%
import os

print("Generated:", len(os.listdir("/content/generated_SDv1-4")))
print("Test:", len(os.listdir("/content/data/test")))
# Out:
# Generated: 301
# Test: 3001

# %%
from PIL import Image
import os

def clean(folder):
    for f in os.listdir(folder):
        path = os.path.join(folder, f)
        try:
            Image.open(path).verify()
        except:
            os.remove(path)

clean("/content/data/test")
clean("/content/generated_SDv1-4")

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os

GEN_DIR = "/content/generated_SDv1-4"

num_images = 36
cols = int(num_images**0.5)
rows = cols

sample_imgs = sorted(os.listdir(GEN_DIR))[:num_images]

plt.figure(figsize=(12,12))

for i, img_name in enumerate(sample_imgs):
    img = Image.open(os.path.join(GEN_DIR, img_name))
    plt.subplot(rows, cols, i+1)
    plt.imshow(img)
    plt.axis("off")

plt.tight_layout()

# %%
from PIL import Image
import os

def clean_resize(folder, size=(256,256)):
    for f in os.listdir(folder):
        path = os.path.join(folder, f)
        try:
            img = Image.open(path).convert("RGB").resize(size)
            img.save(path)
        except:
            os.remove(path)

clean_resize("/content/data/test")
clean_resize("/content/generated_SDv1-4")

# %%
from pytorch_fid import fid_score

fid = fid_score.calculate_fid_given_paths(
    ["/content/data/test", "/content/generated_SDv1-4"],
    batch_size=32,
    device="cuda",
    dims=2048
)

print("FID:", fid)
# Out:
#   0%|          | 0/94 [00:00<?, ?it/s]
#   1%|          | 1/94 [00:00<00:09,  9.83it/s]
#   7%|▋         | 7/94 [00:00<00:02, 36.26it/s]
#  14%|█▍        | 13/94 [00:00<00:01, 44.30it/s]
#  20%|██        | 19/94 [00:00<00:01, 47.98it/s]
#  27%|██▋       | 25/94 [00:00<00:01, 49.91it/s]
#  33%|███▎      | 31/94 [00:00<00:01, 51.27it/s]
#  39%|███▉      | 37/94 [00:00<00:01, 52.11it/s]
#  46%|████▌     | 43/94 [00:00<00:00, 52.60it/s]
#  52%|█████▏    | 49/94 [00:00<00:00, 53.04it/s]
#  59%|█████▊    | 55/94 [00:01<00:00, 53.18it/s]
#  65%|██████▍   | 61/94 [00:01<00:00, 53.27it/s]
#  71%|███████▏  | 67/94 [00:01<00:00, 53.45it/s]
#  78%|███████▊  | 73/94 [00:01<00:00, 53.46it/s]
#  84%|████████▍ | 79/94 [00:01<00:00, 53.53it/s]
#  90%|█████████ | 85/94 [00:01<00:00, 53.62it/s]
# 100%|██████████| 94/94 [00:01<00:00, 49.76it/s]
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  7.63it/s]
#  30%|███       | 3/10 [00:00<00:00, 13.01it/s]
#  50%|█████     | 5/10 [00:00<00:00, 14.78it/s]
#  70%|███████   | 7/10 [00:00<00:00, 15.71it/s]
# 100%|██████████| 10/10 [00:00<00:00, 14.87it/s]
# FID: 83.10825166470045

# %%
import os
import pandas as pd

rows = []

for i in range(300):

    rows.append({
        "image": f"{i:03d}.png",
        "prompt": PROMPTS[i % len(PROMPTS)]
    })

df = pd.DataFrame(rows)

save_path = "/content/generated_SDv1-4/prompts.csv"

df.to_csv(save_path, index=False)

print("Saved prompts.csv")

print("\nExists:")
print(os.path.exists(save_path))

print("\nPreview:")
print(df.head())
# Out:
# Saved prompts.csv
#
# Exists:
# True
#
# Preview:
#      image                                             prompt
# 0  000.png  a face with 5_o_Clock_Shadow, Male, Mouth_Slig...
# 1  001.png  a face with Bags_Under_Eyes, Brown_Hair, Big_N...
# 2  002.png  a face with Black_Hair, Bangs, Smiling, Heavy_...
# 3  003.png  a face with Blond_Hair, Big_Lips, Pale_Skin, S...
# 4  004.png  a face with Brown_Hair, High_Cheekbones, Smili...

# %%
import os
import torch
import pandas as pd

from PIL import Image
from tqdm.auto import tqdm

from transformers import (
    CLIPProcessor,
    CLIPModel
)

GEN_DIR = "/content/generated_SDv1-4"

PROMPT_CSV = os.path.join(
    GEN_DIR,
    "prompts.csv"
)

DEVICE = "cuda"

model = CLIPModel.from_pretrained(
    "openai/clip-vit-base-patch32"
).to(DEVICE)

processor = CLIPProcessor.from_pretrained(
    "openai/clip-vit-base-patch32"
)

df = pd.read_csv(PROMPT_CSV)

scores = []

for _, row in tqdm(df.iterrows(), total=len(df)):

    image_path = os.path.join(
        GEN_DIR,
        row["image"]
    )

    prompt = row["prompt"]

    image = Image.open(image_path).convert("RGB")

    inputs = processor(
        text=[prompt],
        images=image,
        return_tensors="pt",
        padding=True
    ).to(DEVICE)

    with torch.no_grad():

        outputs = model(**inputs)

        image_embeds = outputs.image_embeds
        text_embeds = outputs.text_embeds

        similarity = torch.cosine_similarity(
            image_embeds,
            text_embeds
        ).item()

    scores.append(similarity)

mean_score = sum(scores) / len(scores)

print("\nMean CLIP Similarity:", mean_score)

print("\nMin Score :", min(scores))
print("Max Score :", max(scores))
# Out:
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# CLIPModel LOAD REPORT from: openai/clip-vit-base-patch32
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# vision_model.embeddings.position_ids | UNEXPECTED |  |
# text_model.embeddings.position_ids   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   0%|          | 0/300 [00:00<?, ?it/s]
# Mean CLIP Similarity: 0.2810436507066091
#
# Min Score : 0.20512937009334564
# Max Score : 0.34645336866378784

# %%
import os

GEN_DIR = "/content/generated_SDv1-4"

files = sorted(os.listdir(GEN_DIR))

for i, f in enumerate(files):
    old_path = os.path.join(GEN_DIR, f)
    new_path = os.path.join(GEN_DIR, f"{i:03d}.png")
    os.rename(old_path, new_path)

# %%
import shutil

shutil.make_archive("/content/generated_SDv1-4", 'zip', GEN_DIR)
# Out:
# '/content/generated_SDv1-4.zip'

# %%
from google.colab import files
files.download("/content/generated_SDv1-4.zip")
